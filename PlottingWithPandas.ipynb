# %%
import pandas as pd

# %%
df = pd.read_csv('sbux.csv')

# %%
df['open'].hist();

# %%
df['open'].plot();

# %%
df[['open','high','low','close']].plot.box();

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['open','high','low','close']], alpha= .02 ,figsize=(10, 10));
